# %% [markdown]
# # **Assignment 2 Q2**

# %%
# imports
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split
import numpy as np

# allow plots to appear directly in the notebook
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
data = pd.read_csv('https://raw.githubusercontent.com/klaxmanbabu/Stats-2/main/Credit.csv?token=AOAAKQIUGV5HHAPCB2Q35N27TZQMI', index_col=0)
data.head()
# Out:
#     Income  Limit  Rating  Cards  ...  Married  Ethnicity Balance Defaultee
# 1   14.891   3606     283      2  ...      Yes  Caucasian     333         0
# 2  106.025   6645     483      3  ...      Yes      Asian     903         0
# 3  104.593   7075     514      4  ...       No      Asian     580         0
# 4  148.924   9504     681      3  ...       No      Asian     964         0
# 5   55.882   4897     357      2  ...      Yes  Caucasian     331         0
#
# [5 rows x 12 columns]

# %%
len(data)
# Out:
# 400

# %%
df=data.sample(n=300, random_state=1)

# %%
len(df)
# Out:
# 300

# %%
### STATSMODELS ###

# create a fitted model
lm1 = smf.ols(formula='Income ~ Limit', data=df).fit()

# print the coefficients
lm1.params
# Out:
# Intercept   -12.016186
# Limit         0.012251
# dtype: float64

# %%
### SCIKIT-LEARN ###

# create X and y
feature_cols = ['Limit']
X = df[feature_cols]
y = df.Income

# instantiate and fit
lm2 = LinearRegression()
lm2.fit(X, y)

# print the coefficients
print(lm2.intercept_)
print(lm2.coef_)
# Out:
# -12.016186326416722
# [0.01225131]

# %% [markdown]
# **Plotting the Least Squares Line**

# %%
#sns.pairplot(df, x_vars=['Limit','Rating','Cards','Age','Education','Gender','Balance'], y_vars='Income', size=7, aspect=0.7, kind='reg')

# %% [markdown]
# Print the confidence intervals for the model coefficients

# %%
lm1.conf_int()
# Out:
#                    0         1
# Intercept -17.195208 -6.837165
# Limit       0.011272  0.013231

# %% [markdown]
# Print the p-values for the model coefficients

# %%
lm1.pvalues
# Out:
# Intercept    7.282078e-06
# Limit        9.361489e-74
# dtype: float64

# %% [markdown]
# Print the R-squared value for the model

# %%
lm1.rsquared
# Out:
# 0.6701931715080587

# %%
lm2.score(X, y)
# Out:
# 0.6701931715080588

# %%
### STATSMODELS ###

# create a fitted model
lm1 = smf.ols(formula='Income ~ Limit+Rating', data=df).fit()

# print the coefficients
lm1.params
# Out:
# Intercept   -13.893507
# Limit         0.008987
# Rating        0.048803
# dtype: float64

# %%
### SCIKIT-LEARN ###

# create X and y
feature_cols = ['Limit','Rating']
X = df[feature_cols]
y = df.Income

# instantiate and fit
lm2 = LinearRegression()
lm2.fit(X, y)

# print the coefficients
print(lm2.intercept_)
print(lm2.coef_)
# Out:
# -13.893506551159973
# [0.0089868  0.04880259]

# %%
lm1.conf_int()
# Out:
#                    0         1
# Intercept -23.057190 -4.729823
# Limit      -0.004188  0.022161
# Rating     -0.147602  0.245207

# %%
lm1.pvalues
# Out:
# Intercept    0.003084
# Limit        0.180481
# Rating       0.625200
# dtype: float64

# %%
lm1.rsquared
# Out:
# 0.6704584967048818

# %%
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Income   R-squared:                       0.670
# Model:                            OLS   Adj. R-squared:                  0.668
# Method:                 Least Squares   F-statistic:                     302.1
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):           2.57e-72
# Time:                        07:16:35   Log-Likelihood:                -1339.0
# No. Observations:                 300   AIC:                             2684.
# Df Residuals:                     297   BIC:                             2695.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -13.8935      4.656     -2.984      0.003     -23.057      -4.730
# ...

# %%
### STATSMODELS ###

# create a fitted model
lm1 = smf.ols(formula='Income ~ Limit+Rating+Cards', data=df).fit()

# print the coefficients
lm1.params
# Out:
# Intercept   -13.223911
# Limit         0.003872
# Rating        0.125636
# Cards        -1.259803
# dtype: float64

# %%
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Income   R-squared:                       0.672
# Model:                            OLS   Adj. R-squared:                  0.669
# Method:                 Least Squares   F-statistic:                     202.2
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):           2.46e-71
# Time:                        07:16:42   Log-Likelihood:                -1338.2
# No. Observations:                 300   AIC:                             2684.
# Df Residuals:                     296   BIC:                             2699.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -13.2239      4.686     -2.822      0.005     -22.446      -4.001
# ...

# %%
### STATSMODELS ###

# create a fitted model
lm1 = smf.ols(formula='Income ~ Limit+Rating+Cards+Age', data=df).fit()

# print the coefficients
lm1.params
# Out:
# Intercept   -27.200389
# Limit         0.003414
# Rating        0.131084
# Cards        -1.408863
# Age           0.260297
# dtype: float64

# %%
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Income   R-squared:                       0.687
# Model:                            OLS   Adj. R-squared:                  0.682
# Method:                 Least Squares   F-statistic:                     161.6
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):           4.78e-73
# Time:                        07:16:49   Log-Likelihood:                -1331.4
# No. Observations:                 300   AIC:                             2673.
# Df Residuals:                     295   BIC:                             2691.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -27.2004      5.941     -4.578      0.000     -38.893     -15.508
# ...

# %%
### STATSMODELS ###

# create a fitted model
lm1 = smf.ols(formula='Income ~ Limit+Rating+Cards+Age+Education', data=df).fit()

# print the coefficients
lm1.params
# Out:
# Intercept   -24.866948
# Limit         0.003642
# Rating        0.127677
# Cards        -1.413199
# Age           0.260855
# Education    -0.163681
# dtype: float64

# %%
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Income   R-squared:                       0.687
# Model:                            OLS   Adj. R-squared:                  0.681
# Method:                 Least Squares   F-statistic:                     128.9
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):           5.94e-72
# Time:                        07:16:56   Log-Likelihood:                -1331.3
# No. Observations:                 300   AIC:                             2675.
# Df Residuals:                     294   BIC:                             2697.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -24.8669      8.148     -3.052      0.002     -40.904      -8.830
# ...

# %%
### STATSMODELS ###

# create a fitted model
lm1 = smf.ols(formula='Income ~ Limit+Rating+Cards+Age+Education+Balance', data=df).fit()

# print the coefficients
lm1.params
# Out:
# Intercept   -42.160651
# Limit         0.010845
# Rating        0.180780
# Cards        -0.275571
# Age           0.087962
# Education     0.083095
# Balance      -0.062530
# dtype: float64

# %%
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Income   R-squared:                       0.832
# Model:                            OLS   Adj. R-squared:                  0.828
# Method:                 Least Squares   F-statistic:                     241.3
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):          3.24e-110
# Time:                        07:17:04   Log-Likelihood:                -1238.2
# No. Observations:                 300   AIC:                             2490.
# Df Residuals:                     293   BIC:                             2516.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -42.1607      6.082     -6.932      0.000     -54.131     -30.190
# ...

# %% [markdown]
# Results

# %% [markdown]
# Based on the analysis the best model is the R2, Cp, and AIC scores is last which includes all the variables - Limit+Rating+Cards+Age+Education+Balance

# %% [markdown]
# **c. Now repeat (b) by including the qualitative predictors (like Gender, Student, Married, Ethnicity and Balance) also and report on the best model that predicts the income of a person.**

# %%
df.head()
# Out:
#       Income  Limit  Rating  ...         Ethnicity  Balance  Defaultee
# 399   37.728   2525     192  ...         Caucasian        0          0
# 126   27.578   2531     195  ...         Caucasian        0          0
# 329   41.192   3673     297  ...         Caucasian      121          0
# 340  149.316  10278     707  ...  African American     1107          1
# 173   76.348   4697     344  ...             Asian      108          0
#
# [5 rows x 12 columns]

# %%
### STATSMODELS ###

# create a fitted model
lm1 = smf.ols(formula='Income ~ Limit+Rating+Cards+Age+Education+Balance', data=df).fit()

# print the coefficients
lm1.params
# Out:
# Intercept   -42.160651
# Limit         0.010845
# Rating        0.180780
# Cards        -0.275571
# Age           0.087962
# Education     0.083095
# Balance      -0.062530
# dtype: float64

# %%
#convert gender column into category datatype
df.Gender.astype("category").cat.codes
df.Married.astype("category").cat.codes
df.Student.astype("category").cat.codes
df.Ethnicity.astype("category").cat.codes
# Out:
# 399    2
# 126    2
# 329    2
# 340    0
# 173    1
#       ..
# 211    2
# 241    1
# 58     2
# 307    2
# 37     2
# Length: 300, dtype: int8

# %%
df=pd.get_dummies(df, columns=['Gender'])
df=pd.get_dummies(df, columns=['Married'])
df=pd.get_dummies(df, columns=['Student'])
df=pd.get_dummies(df, columns=['Ethnicity'])

# %%
df=df.rename(columns={"Ethnicity_African American": "Ethnicity_African_American"})

# %%
### STATSMODELS ###

# create a fitted model
lm1 = smf.ols(formula='Income ~ Gender_Female+Gender_Male', data=df).fit()

# print the coefficients
lm1.params
# Out:
# Intercept        30.272662
# Gender_Female    15.288714
# Gender_Male      14.983948
# dtype: float64

# %%
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Income   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                  0.002578
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):              0.997
# Time:                        07:18:41   Log-Likelihood:                -1505.5
# No. Observations:                 300   AIC:                             3017.
# Df Residuals:                     297   BIC:                             3028.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
### STATSMODELS ###

# create a fitted model
lm1 = smf.ols(formula='Income ~ Gender_Female+Gender_Male+Married_No+Married_Yes', data=df).fit()

# print the coefficients
lm1.params
# Out:
# Intercept        22.542388
# Gender_Female    11.401775
# Gender_Male      11.140613
# Married_No        9.798142
# Married_Yes      12.744246
# dtype: float64

# %%
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Income   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.2321
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):              0.793
# Time:                        07:18:48   Log-Likelihood:                -1505.2
# No. Observations:                 300   AIC:                             3016.
# Df Residuals:                     297   BIC:                             3028.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
### STATSMODELS ###

# create a fitted model
lm1 = smf.ols(formula='Income ~ Gender_Female+Gender_Male+Married_No+Married_Yes+Ethnicity_African_American+Ethnicity_Asian+Ethnicity_Caucasian', data=df).fit()

# print the coefficients
lm1.params
# Out:
# Intercept                     19.625460
# Gender_Female                  9.855003
# Gender_Male                    9.770457
# Married_No                     7.785447
# Married_Yes                   11.840013
# Ethnicity_African_American    12.272007
# Ethnicity_Asian                3.228682
# Ethnicity_Caucasian            4.124771
# dtype: float64

# %%
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Income   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.7973
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):              0.528
# Time:                        07:18:55   Log-Likelihood:                -1503.9
# No. Observations:                 300   AIC:                             3018.
# Df Residuals:                     295   BIC:                             3036.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
### STATSMODELS ###

# create a fitted model
#lm1 = smf.ols(formula='Income ~ Gender+Married+Student+Ethnicity+Balance', data=df).fit()

# print the coefficients
#lm1.params

# %%
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Income   R-squared:                       0.302
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                     21.15
# Date:                Fri, 30 Oct 2020   Prob (F-statistic):           1.32e-20
# Time:                        15:51:08   Log-Likelihood:                -1451.5
# No. Observations:                 300   AIC:                             2917.
# Df Residuals:                     293   BIC:                             2943.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %%
### STATSMODELS ###

# create a fitted model
lm1 = smf.ols(formula='Income ~ Gender_Female+Gender_Male+Married_No+Married_Yes+Student_No+Student_Yes+Ethnicity_African_American+Ethnicity_Asian+Ethnicity_Caucasian+Balance', data=df).fit()

# print the coefficients
lm1.params
# Out:
# Intercept                      5.899822
# Gender_Female                  3.851961
# Gender_Male                    2.047861
# Married_No                     1.222585
# Married_Yes                    4.677237
# Student_No                    11.286540
# Student_Yes                   -5.386719
# Ethnicity_African_American     5.063524
# Ethnicity_Asian               -0.171295
# Ethnicity_Caucasian            1.007592
# Balance                        0.043014
# dtype: float64

# %%
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Income   R-squared:                       0.302
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                     21.15
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):           1.32e-20
# Time:                        07:19:07   Log-Likelihood:                -1451.5
# No. Observations:                 300   AIC:                             2917.
# Df Residuals:                     293   BIC:                             2943.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Results

# %% [markdown]
# Including all categorical variables model is the best fit model

# %%
from scipy.stats import pearsonr
from statsmodels.stats.anova import anova_lm

# %% [markdown]
# **D.Check if Limit and Balance is correlated (Correlation Coefficient >0.6). In that case include the interaction of these parameters in your model and print the ANOVA table and the R2 obtained using the test data.**

# %%
df_test=data.merge(df, how = 'outer' ,indicator=True).loc[lambda x : x['_merge']=='left_only']

# %%
len(df_test)
# Out:
# 100

# %%
corr, _ = pearsonr(df_test.Income, df_test.Limit)
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.675

# %%
corr, _ = pearsonr(df_test.Income, df_test.Rating)
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.675

# %%
corr, _ = pearsonr(df_test.Income, df_test.Cards)
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: -0.100

# %%
corr, _ = pearsonr(df_test.Income, df_test.Age)
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.221

# %%
corr, _ = pearsonr(df_test.Income, df_test.Education)
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: -0.078

# %%
corr, _ = pearsonr(df_test.Income, df_test.Balance)
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.193

# %%
### STATSMODELS ###

# create a fitted model with all three features
lm1 = smf.ols(formula='Income ~ Limit + Rating ', data=df_test).fit()

# print the coefficients
lm1.params
# Out:
# Intercept   -14.315469
# Limit         0.005590
# Rating        0.087102
# dtype: float64

# %% [markdown]
# ANOVA TABLE

# %%
print(anova_lm(lm1))
# Out:
#             df        sum_sq       mean_sq          F        PR(>F)
# Limit      1.0  42925.584621  42925.584621  81.186513  1.836687e-14
# Rating     1.0    111.266757    111.266757   0.210442  6.474472e-01
# Residual  97.0  51286.618260    528.728023        NaN           NaN

# %% [markdown]
# R2 squared

# %%
lm1.rsquared
# Out:
# 0.4562687477834291

# %%
lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Income   R-squared:                       0.456
# Model:                            OLS   Adj. R-squared:                  0.445
# Method:                 Least Squares   F-statistic:                     40.70
# Date:                Sun, 01 Nov 2020   Prob (F-statistic):           1.47e-13
# Time:                        07:21:47   Log-Likelihood:                -453.89
# No. Observations:                 100   AIC:                             913.8
# Df Residuals:                      97   BIC:                             921.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -14.3155      9.929     -1.442      0.153     -34.022       5.391
# ...
